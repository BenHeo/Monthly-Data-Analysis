# %%
import pandas as pd
import numpy as np
import json

# %%
pd.read_json('./samsunghealth_821086531644_201902021145/jsons/com.samsung.health.exercise/00bef178-06b4-42bd-a2d6-7cad4cf0c0b1.location_data.json')
# Out:
#    accuracy   latitude   longitude          start_time  version
# 0     20.00  37.547858  126.837071 2018-04-27 11:35:00        2
# 1     19.65  37.548142  126.840908 2018-04-27 11:40:00        2
# 2     24.00  37.549169  126.843515 2018-04-27 11:45:00        2
# 3     35.00  37.549689  126.844652 2018-04-27 11:50:00        2

# %%
pd.read_json('./samsunghealth_821086531644_201902021145/jsons/com.samsung.health.exercise/00bef178-06b4-42bd-a2d6-7cad4cf0c0b1.live_data.json')
# Out:
#     calorie    distance  segment     speed              start_time
# 0      4.13   77.950004        1  1.390620 2018-04-27 11:34:00.219
# 1      4.50   90.210000        1  1.684044 2018-04-27 11:35:00.000
# 2      4.36   84.310000        1  1.447826 2018-04-27 11:36:00.000
# 3      4.48   88.150001        1  1.537624 2018-04-27 11:37:00.347
# 4      6.23  109.940002        1  2.055556 2018-04-27 11:38:00.000
# 5      5.61  100.080002        1  1.916667 2018-04-27 11:39:00.000
# 6      4.20   81.220000        1  1.437304 2018-04-27 11:40:00.000
# 7      4.64   86.049998        1  1.440342 2018-04-27 11:41:00.175
# 8      4.89   82.300003        1  1.500000 2018-04-27 11:42:00.000
# 9      4.46   84.010002        1  1.583333 2018-04-27 11:43:00.000
# 10     6.39   73.820000        1  1.416667 2018-04-27 11:44:00.000
# 11     4.40   87.040001        1  1.583333 2018-04-27 11:45:00.000
# 12     4.24   83.779999        1  1.611111 2018-04-27 11:46:00.000
# ...

# %%
with open('./samsunghealth_821086531644_201902021145/jsons/com.samsung.shealth.activity.day_summary/f85d7975-ec8d-428f-ad60-4b5d5bcebf53.extra_data.json') as f:
    data = json.load(f)
#list(data.keys())
#pd.DataFrame.from_dict(data, orient='index')
pd.DataFrame(data['mActivityList',
 'mAdaptiveGoal',
 'mIsGoalAchieved',
 'mIsMostActiveAchieved',
 'mMostActiveMinutes',
 'mStreakDayCount',
 'mUnitDataList'])
# Out:
#    mActiveTime  mActiveTimeType  mCalorie  mCategory  \
# 0       669602                0     43.96        204
#
#                           mDetailInfoId  mDistance  mDuration  mEndTime  \
# 0  08c0a61c-a5e3-4d15-9abb-11ff42b4dd1f     816.51     670000  76930000
#
#    mStartTime  mType
# 0    76260000   1001

# %%
list(data.values())
# Out:
# [[{'mActiveTime': 669602,
#    'mActiveTimeType': 0,
#    'mCalorie': 43.96,
#    'mCategory': 204,
#    'mDetailInfoId': '08c0a61c-a5e3-4d15-9abb-11ff42b4dd1f',
#    'mDistance': 816.51,
#    'mDuration': 670000,
#    'mEndTime': 76930000,
#    'mStartTime': 76260000,
#    'mType': 1001}],
#  0,
#  False,
#  False,
#  0,
#  0,
#  [{'distance': 39.049995,
#    'mCalorie': 2.0799997,
#    'mOthersTime': 0,
#    'mRunTime': 1200,
#    'mStartTime': 22200000,
#    'mTimeUnit': 600000,
#    'mWalkTime': 30015,
#    'runStep': 3,
#    'walkStep': 45},
#   {'distance': 7.07,
#    'mCalorie': 0.34,
#    'mOthersTime': 0,
#    'mRunTime': 0,
#    'mStartTime': 24000000,
#    'mTimeUnit': 600000,
#    'mWalkTime': 5336,
#    'runStep': 0,
#    'walkStep': 8},
#   {'distance': 108.38,
#    'mCalorie': 5.7799997,
#    'mOthersTime': 0,
#    'mRunTime': 0,
#    'mStartTime': 25200000,
#    'mTimeUnit': 600000,
#    'mWalkTime': 96048,
#    'runStep': 0,
#    'walkStep': 144},
# ...

# %%
pd.DataFrame(data['mAdaptiveGoal'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-5a220329579c> in <module>()
# ----> 1 pd.DataFrame(data['mAdaptiveGoal'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     465                                    dtype=values.dtype, copy=False)
#     466             else:
# --> 467                 raise ValueError('DataFrame constructor not properly called!')
#     468
#     469         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
pd.DataFrame(data['mUnitDataList'])
# Out:
#       distance   mCalorie  mOthersTime  mRunTime  mStartTime  mTimeUnit  \
# 0    39.049995   2.080000            0      1200    22200000     600000
# 1     7.070000   0.340000            0         0    24000000     600000
# 2   108.380000   5.780000            0         0    25200000     600000
# 3   674.769960  35.629997            0         0    25800000     600000
# 4     7.370000   0.490000            0         0    26400000     600000
# 5   287.800000  15.709999            0         0    27600000     600000
# 6   394.400000  20.599998            0       660    28200000     600000
# 7   249.079990  13.259999            0      7463    28800000     600000
# 8    33.789997   2.040000            0         0    33000000     600000
# 9     5.520000   0.280000            0         0    34200000     600000
# 10   31.369999   1.740000            0         0    34800000     600000
# 11   11.709999   0.540000            0         0    37200000     600000
# ...

# %%
with open('./samsunghealth_821086531644_201902021145/jsons/com.samsung.shealth.step_daily_trend/0a60246d-7150-429e-85e6-6b4c9d9324e6.binning_data.json') as f:
    data = json.load(f)
    
pd.DataFrame(data).head()
# Out:
#      calorie  count    distance     speed
# 0   0.000000      0    0.000000  0.000000
# 1   0.000000      0    0.000000  0.000000
# 2   0.000000      0    0.000000  0.000000
# 3  23.240001    582  447.009993  5.062673
# 4   2.550000     64   48.959999  5.100000

# %%
with open('./samsunghealth_821086531644_201902021145/jsons/com.samsung.shealth.step_daily_trend/0a60246d-7150-429e-85e6-6b4c9d9324e6.binning_data.json') as f:
    data = json.load(f)

pd.DataFrame(data).head()
# Out:
#      calorie  count    distance     speed
# 0   0.000000      0    0.000000  0.000000
# 1   0.000000      0    0.000000  0.000000
# 2   0.000000      0    0.000000  0.000000
# 3  23.240001    582  447.009993  5.062673
# 4   2.550000     64   48.959999  5.100000
